# %% [markdown]
# ## ドライブのマウント

# %%
# !pip install -qU torch==1.7.1 torchtext==0.8.0 torchvision==0.8.2 torchaudio==0.7.2
# !pip install -q transformers==4.4.2 pytorch_lightning==1.2.1 sentencepiece
# !pip install fugashi
# !pip install ipadic

# %% [markdown]
# ## 生成器の準備

# %%
from tqdm.auto import tqdm
import pandas as pd
from pprint import pprint

INPUT_MAX_LEN = 512  # モデルに入力されるトークン列の最大長。最大長を超えたトークンは切り捨てられる。
OUTPUT_MAX_LEN = 128  # モデルから出力されるトークン列の最大長。最大長を超えないように文が生成されるはず。
AQG_DIR = "../AQG_FINETUNE/model"

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import T5ForConditionalGeneration, T5Tokenizer

# トークナイザー（SentencePiece）
aqg_tokenizer = T5Tokenizer.from_pretrained(AQG_DIR, is_fast=True)

# 学習済みモデル
aqg_model = T5ForConditionalGeneration.from_pretrained(AQG_DIR)

# GPUの利用有無
USE_GPU = torch.cuda.is_available()
if USE_GPU:
    aqg_model.cuda()
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# ## 識別器の準備

# %%
import pandas as pd
from transformers import AutoTokenizer
import torch
from torch import optim
from torch import nn
import pytorch_lightning as pl

# %%
INPUT_MAX_LEN=512
PRETRAINED_MODEL_NAME = "cl-tohoku/bert-base-japanese-char-whole-word-masking"
DIS_CHECKPOINT = "../DIS_FINETUNE/checkpoint/best_loss_epoch=2.ckpt"

# %%
class FineTuneBert(pl.LightningModule):
    def __init__(self, model_name_or_path, n_classes, n_epochs=None):
        super().__init__()

        self.model = BertModel.from_pretrained(model_name_or_path, return_dict=True)
        self.classifier = nn.Linear(self.model.config.hidden_size, n_classes)
        self.n_epoch = n_epochs
        self.criterion = nn.CrossEntropyLoss()

        ## BertLayerモジュールの最後を勾配計算ありに変更
        for param in self.model.parameters():
            param.requires_grad = False
        for param in self.model.encoder.layer[-1].parameters():
            param.requires_grad = True

    def forward(self, input_ids, attention_mask, labels=None):
        output = self.model(input_ids, attention_mask=attention_mask)
        preds = self.classifier(output.pooler_output)
        loss = 0
        if labels is not None:
            loss = self.criterion(preds, labels)

        return loss, preds

# %%
import torch
from transformers import BertModel, AutoTokenizer
from torchvision import models

# トークナイザー
dis_tokenizer = AutoTokenizer.from_pretrained(PRETRAINED_MODEL_NAME)

# 学習済モデル
dis_model = FineTuneBert(PRETRAINED_MODEL_NAME, n_classes=2)
checkpoint = torch.load(DIS_CHECKPOINT, map_location=torch.device('cpu'))
dis_model.load_state_dict(checkpoint["state_dict"])

# GPU利用の有無
USE_GPU = torch.cuda.is_available()
if USE_GPU:
    dis_model.cuda()

# %% [markdown]
# ## データセット

# %%
test_dataset = "./data/test.csv"
question_data_list = []

df = pd.read_csv(test_dataset)

for index, row in df.iterrows():
    question_data_list.append((row["answer"], row["passage"], row["question"]))

# %% [markdown]
# ## 問題生成

# %%
from pytorch_lightning.callbacks import early_stopping
generated_questions = []

dis_model.eval()

for answer, context, example in tqdm(question_data_list):
    # モデルに入力可能な形式に変換する。
    input = f"answer: {answer.lower()} context: {context.lower()}"

    # 入力文をトークナイズする。
    tokenized_inputs = aqg_tokenizer.batch_encode_plus(
        [input], max_length=INPUT_MAX_LEN, truncation=True, 
        padding="longest", return_tensors="pt")

    input_ids = tokenized_inputs['input_ids']
    input_mask = tokenized_inputs['attention_mask']
    if torch.cuda.is_available():
        input_ids = input_ids.cuda()
        input_mask = input_mask.cuda()

    # 問題文を生成する。
    tokenized_outputs = aqg_model.generate(input_ids=input_ids, attention_mask=input_mask, 
        max_length=OUTPUT_MAX_LEN, return_dict_in_generate=True, decoder_start_token_id=0,
        # temperature=1.0,  # 生成にランダム性を入れる温度パラメータ
        num_beams=20,  # ビームサーチの探索幅
        # diversity_penalty=0.1,#1.0,  # 生成結果の多様性を生み出すためのペナルティパラメータ
        # num_beam_groups=4,  # ビームサーチのグループ
        num_return_sequences=20,  # 生成する文の数
        repetition_penalty=10.0, # 同じ文の繰り返し（モード崩壊）へのペナルティ
        # ,early_stopping=True
    )

    # 生成された問題文のトークン列を文字列に変換する。
    outputs = [aqg_tokenizer.decode(ids, skip_special_tokens=True, clean_up_tokenization_spaces=False) 
        for ids in tokenized_outputs.sequences]

    
    ## 問題の識別
    questions = []
    for question in outputs:
        ## 入力する形式に変換
        input = question + "答えは" + answer

        ## tokenize
        tokenized_input = dis_tokenizer.batch_encode_plus(
            [input],
            max_length=INPUT_MAX_LEN,
            truncation=True,
            add_special_tokens=True,
            padding="longest",
            return_tensors="pt"
        )

        input_ids = tokenized_input["input_ids"]
        input_mask = tokenized_input["attention_mask"]

        ## デバイスの指定
        if torch.cuda.is_available():
            input_ids = input_ids.cuda()
            input_mask = input_mask.cuda()

        ## 識別
        with torch.no_grad():
            _, score = dis_model(input_ids, input_mask)
            questions.append([question, score])
        
    generated_questions.append(questions)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %% [markdown]
# ## 出力&保存

# %%
import textwrap

csv_outputs = []

for (answer, context, example), questions in zip(question_data_list, generated_questions):
  print(f"answer: {answer}")
  print("\n".join(textwrap.wrap(f"context:{context}")))
  print(f"example: {example}")
  for question, score in questions:
    pred = torch.argmax(score)
    
    # tf = "○" if pred==1 else "×"

    ## 適切な問題のみ出力
    if pred==1:
      csv_outputs.append([answer, context, question])
      # print(f"  -> {tf} {score} {question}")
      print(f"  -> {question}")
  print()
  
df = pd.DataFrame(csv_outputs, columns=["answer", "passage", "question"])
df.to_csv("./generated/pipline.csv")
# Out:
# answer: 正しい
# context:どのようなアルゴリズムでも、処理の流れは、順次、分岐、反復の3つの構造の組み合わせで構成されている。このような処理の流れを制
# 御構造という。順次とは1つ1つの処理を順番に行うことであり、分岐はある条件に応じて異なる処理を実行することである。また、反復はある条件が満た
# されている間はその処理を繰り返し実行することである。
# example: 次の文章は正しいか答えなさい。どのようなアルゴリズムでも、処理の流れは、順次、分岐、反復の3つの構造の組み合わせで構成されている。
#   -> 次の文章は正しいか答えなさい。順次、分岐、反復の3つの構造の組み合わせで構成されている。
#   -> 次の文章は正しいか答えなさい。処理の流れは順次、分岐、反復の3つの構造の組み合わせで構成されている。
#   -> 次の文章は正しいですか?処理の流れは順次、分岐、反復の3つの構造の組み合わせで構成されている。
#   -> 次の文章は正しいか答えなさい。順次、分岐、反復の3つの構造の組み合わせで構成されている複雑な処理の流れを制御構造という。
#   -> 次の文章は正しいか答えなさい。反復はある条件に応じて異なる処理を実行することである。
#   -> 次の文章は正しいですか?順次、分岐、反復の3つの構造の組み合わせで構成されている。
#   -> 次の文章は正しいか答えなさい。反復とはある条件に応じて異なる処理を実行することである。
#   -> 次の文章は正しいか答えよ。順次、分岐、反復の3つの構造の組み合わせで構成されている。
#   -> 次の文章は正しいか答えなさい。順次、分岐、反復の3つの構造の組み合わせで構成されており、これらの処理の流れを制御構造という。
#   -> 次の文章は正しいですか?処理の流れは順次、分岐、反復の3つの構造で構成されている。
#   -> 次の文章は正しいか答えなさい。処理の流れは順次、分岐、反復の3つの構造で構成されており、これらの組み合わせを制御構造という。
#   -> 次の文章は正しいか答えなさい。処理の流れは、順次、分岐、反復の3つの構造の組み合わせで構成されている。
#   -> 次の文章は正しいか答えなさい。順次、分岐、反復の3つの構造を組み合わせた構成で構成されている。
#   -> 次の文章は正しいですか?処理の流れは順次、分岐、反復の3つの構造で構成されています。
#   -> 次の文章は正しいか答えなさい。処理の流れは順次、分岐、反復の3つの構造で構成されています。
#   -> 次の文章は正しいですか。処理の流れは順次、分岐、反復の3つの構造の組み合わせで構成されている。
#   -> 次の文章は正しいか答えなさい。処理の流れは順次、分岐、反復の3つの構造で構成されている。
#   -> 次の文章は正しいか答えなさい。順次、分岐、反復の3つの構造で構成されており、これらの処理の流れを制御構造という。
#   -> 次の文章は正しいですか?処理の流れは、順次、分岐、反復の3つの構造の組み合わせで構成されている。
#   -> 次の文章は正しいか答えよ。処理の流れは順次、分岐、反復の3つの構造の組み合わせで構成されている。
#
# answer: cpuの動作速度が速く、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuとなる。
# context:cpuの動作速度が速いほど、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuとなる。
# example: 性能の良いcpuとはどのようなものでしょう
#   -> cpuの動作速度が速いほど性能の良いcpuとなるものは何か
#   -> cpuの動作速度が速く、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuとなるものは何か
#   -> cpuの動作速度が速く、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuはどうなるか。
#   -> cpuの動作速度が速いほど性能の良いcpuはどうなるか。
#   -> cpuの動作速度が速く、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuは何か
#   -> cpuの動作速度が速く、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuはどうなるか
#   -> cpuの動作速度が速く、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuとなるか。
#   -> cpuの動作速度が速く、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuとなるか答えなさい。
#   -> cpuの動作速度が速く、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuはどうなるだろうか
#   -> cpuの動作速度が速く、1動作あたりに実行する命令や処理するデータが少ないほど性能の良いcpuとなるものは何か
#
# answer: 正しくない
# context:pythonでは分岐にはif/elseを使い、反復にはwhile、forを使用する。
# example: 次の文章は正しいですか?pythonでは分岐にはwhile、forを使用する。
#   -> pythonでは分岐にはif/else、反復にはforを使用する。
#   -> pythonでは分岐にはif/elseを使用し、反復にはwhile、forを使用する。
#   -> pythonでは分岐にはif/elseを使い、反復にはwhile、forを使用する。
#   -> 次の文章は正しいか答えなさい。pythonでは分岐にはif/else、反復にはforを使用する。
#   -> pythonでは分岐にはif/else、反復にはforを使用する。 次の文章は正しいか答えなさい。
#   -> pythonでは分岐にはif/else、反復にはforを使用する。文章は正しいか答えなさい。
#   -> pythonでは分岐にはif/else、反復にはforを使用する。次の文章は正しいか答えなさい。
#   -> pythonで分岐にはif/else、forを使用する。次の文章は正しいか答えなさい。
#   -> pythonでは分岐にはif/elseを使用し、反復にはforを使用する。
#   -> pythonの分岐にはif/else、forを使用する。次の文章は正しいか答えなさい。
#   -> pythonで分岐にはif/elseを使用し、反復にはwhile、forを使用する。
#   -> pythonで分岐にはif/else、forを使用する。文章は正しいか答えなさい。
#   -> 次の文章は正しいか答えなさい。pythonでは分岐にはif/else、反復にはwhile、forを使用する。
#   -> pythonでは分岐にはif/else、反復にはwhile、forを使用する。
#   -> pythonでの分岐にはif/elseを使用し、反復にはwhile、forを使用する。
#   -> 次の文章は正しいか答えなさい。pythonでは分岐にはif/elseを使い、反復にはwhile、forを使用する。
#   -> pythonで分岐にはif/elseを使い、反復にはwhile、forを使用する。
#   -> pythonでは分岐にはif/elseを使用し、反復にはwhile、forを使用する。 次の文章は正しいか答えなさい。
#   -> pythonでは分岐にはif/elseを使用し、反復にはforを使用する。 次の文章は正しいか答えなさい。
#   -> pythonでは分岐にはif/else、反復にはforを使用する。答えなさい。
#
# answer: 正しくない
# context:現在のコンピュータの演算装置は、0か1のみで表現される2進数を扱うように設計されている。2進数を大きな桁で非常に高速で演算す
# ることによりすべての演算を行う。その基本的な演算は四則演算とは異なりand、or、notの3つである。
# example: 次の文章は正しいか答えなさい。現在のコンピュータの演算装置は、0から9で表現される10進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。2進数を大きな桁で非常に高速に演算することによりすべての演算を行う。
#   -> 次の文章は正しいか答えなさい。2進数を扱うように設計されたコンピュータの演算装置は、0か1のみで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいですか?コンピュータの演算装置は0か1のみで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。2進数の基本的な演算は四則演算とは異なりand、or、notの3つである。
#   -> 次の文章は正しいか答えなさい。2進数を扱うように設計されたコンピュータの演算装置は、0か1だけで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。現代コンピュータの演算装置は0か1のみで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。2進数を扱うように設計されているため、0か1のみで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。新しいコンピュータの演算装置は0か1のみで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。2進数を扱うように設計されたため、0か1のみで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。現在のコンピュータの演算装置は0か1のみで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。コンピュータの演算装置は0か1のみで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。2進数を扱うように設計されているため、0か1だけで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。2進数を扱うように設計されたため、0か1だけで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいですか?コンピュータの演算装置は、0か1のみで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいですか?コンピュータの演算装置は0か1だけで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。コンピュータの演算装置は、0か1のみで表現される2進数を扱うように設計されている。
#   -> 次の文章は正しいか答えなさい。その基本的な演算は四則演算とは異なりand、or、notの3つである。
#   -> 次の文章は正しいか答えなさい。4則演算とは異なりand、or、notの3つである。
#   -> 次の文章は正しいですか?2進数を大きな桁で非常に高速に演算することによりすべての演算を行う。
#   -> 次の文章は正しいか答えなさい。四則演算とは異なりand、or、notの3つである。
#
# answer: アイソタイプの目的は、言語の壁を越えて情報を伝達することで、社会的不平等を解消することである。
# context:オットー・ノイラートが考案したアイソタイプは、文字が読めない社会的弱者を含めた、あらゆる人々に向けて、情報をグラフィカルに伝
# 達しようとしたものである。その目的は、言語の壁を越えて情報を伝達することで、社会的な不平等を解消しようとしたものと言われている。
# example: アイソタイプの目的は何か、答えなさい。
#   -> オットー・ノイラートが考案したアイソタイプの目的は何ですか?
#   -> オットー・ノイラートが考案したアイソタイプとは何ですか?
#   -> オットー・ノイラートが考案したアイソタイプの目的は何ですか
#   -> オットー・ノイラートが考案したアイソタイプの目的は何か
#   -> オットー・ノイラートが考案したアイソタイプの目的は何か、答えなさい。
#   -> オットー・ノイラートが考案したアイソタイプの目的は何か?
#   -> オットー・ノイラートが考案したアイソタイプの目的は何か。
#   -> オットー・ノイラートが考案したアイソタイプの目的は何でしたか?
#   -> オットー・ノイラートが考案したアイソタイプの特徴は何ですか?
#   -> オットー・ノイラートが考案したアイソタイプの主な目的は何ですか?
#   -> オットー・ノイラートが考案したアイソタイプの目的は何か、説明しなさい。
#   -> オットー・ノイラートが考案したアイソタイプの目的は何か答えなさい。
#   -> オットー・ノイラートが考案したアイソタイプの目的は何か説明しなさい。
#   -> アイソタイプとは何ですか?
#   -> オットー・ノイラートが考案したアイソタイプを説明せよ。
#   -> オットー・ノイラートが考案したアイソタイプの目的は何ですか。
#   -> アイソタイプとは何ですか
#   -> オットー・ノイラートが最初に考案したアイソタイプの目的は何ですか?
#   -> オットー・ノイラートが考案したアイソタイプの主な目的は何か
#
# answer: 正しくない
# context:離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。一つの例として、2次
# 元配列を用いて表現することができる。頂点どうしがつながっていれば1、つながっていなければ0として表現する。このように表現する方法を隣接行列と
# いう。隣接行列を用いて表現する場合、辺の本数が少ない場合には、隣接行列の要素の多くが0である疎行列になってしまう。
# example: 次の文章は正しいか答えてください。離散グラフを隣接行列を用いて表現する場合、辺の本数が少ない場合には蜜行列となる。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータで表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいですか?離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えよ。離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいですか。離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータ上で表現するにあたり、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えてください。離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいですか?離散グラフをコンピュータで表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータ上で表現するには、コンピュータで処理できるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式で表現する必要があります。
#   -> 次の文章は正しいか答えよ。離散グラフをコンピュータで表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式を用いて表現する必要がある。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータ上で表現するには、コンピュータで取り扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式で表現しなければならない。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータ上で表現するには、コンピュータで扱ことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータ上で表現するには、コンピューターで扱うことができるデータ形式で表現する必要がある。
#   -> この文章は正しいか答えなさい。離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えてください。離散グラフをコンピュータで表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいですか。離散グラフをコンピュータで表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。
#   -> 次の文章は正しいか答えなさい。離散グラフをコンピュータで表現するにあたり、コンピュータで扱うことができるデータ形式で表現する必要がある。
#
# answer: プライバシーの権利
# context:19世紀末に米国の法律家であるサミュエル・d・ウォーレンスとルイス・d・ブランダイスが,一人にしておいてもらう権利(私生活を
# みだりに他人の目にさらされない権利)として「プライバシーの権利」を主張した。
# example: 19世紀末にサミュエル・d・ウォーレンスとルイス・d・ブランダイスにより提唱された、私生活をみだりに他人の目にさらされない権利の名称は?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスが主張したプライバシーの権利は何ですか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したか
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされない権利として何を主張したか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされない権利として何を主張したか
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは,一人にしておいてもらう権利として何を主張したか?
#   -> 19世紀末にサミュエル・d・ウォーレンスとルイス・d・ブランダイスが主張したプライバシーの権利は何ですか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したのか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされないこと権利として何を主張したか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされないこと権利として何を主張したか
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスはどのような権利を主張したか
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したのだろうか
#   -> 19世紀末に米国法律家サミュエル・d・ウォーレンスとルイス・d・ブランダイスが主張したプライバシーの権利は何ですか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、一人にしておいてもらう権利として何を主張したか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは私生活をみだりに他人の目にさらされない権利として何を主張したか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したのか
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスが主張したプライバシーの権利の名前は何ですか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは私生活をみだりに他人の目にさらされない権利として何を主張したか
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされない権利として何を主張したのか?
#   -> サミュエル・d・ウォーレンスとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したのですか?
#
# answer: 関数を用いることでプログラムを機能ごとに整理、構造化することが可能となる。また、作成した関数はメインコード内で何回でも呼び出すことが可能となるため、作成した機能を再利用することが可能となる。
# context:一般にシステム開発などで行われるプログラムは大規模なので、コードの長さも膨大となる。このような場合、文章の章、節、段落のよう
# な適切な構造を作らないと、コードの可動性は著しく低くなってしまう。そこでプログラムの機能ごとにメインコードから切り離し、関数という単位で分割
# することで、プログラムを機能ごとに整理、構造化することが可能となる。また、作成した関数はメインコード内で何回でも呼び出すことが可能となるため
# 、作成した機能を再利用することが可能となる。
# example: 関数を用いることにどのようなメリットがあるか
#
# answer: 選択ソートはリスト内のデータから最小値を探索し、最小値から順に取り出すことで並べ替えを実現するアルゴリズムである。
# context:選択ソートはリスト内のデータから最小値を探索し、最小値から順に取り出すことで並べ替えを実現するアルゴリズムである。
# example: 選択ソートとはどのようなアルゴリズムか
#   -> 選択ソートはどのようなアルゴリズムか説明しなさい
#   -> 選択ソートがリスト内のデータから最小値を探索し、最小値から順に取り出すことで並べ替えを実現するアルゴリズムは何か
#   -> 選択ソートはどのようなアルゴリズムか答えなさい。
#   -> 選択ソートはどのようなアルゴリズムか説明しなさい。
#   -> 選択ソートがリスト内のデータから最小値を探索し、最小値から順に取り出すことで並べ替えを実現するアルゴリズムは何か。
#   -> 選択ソートはどのようなアルゴリズムか答えなさい
#   -> 選択ソートはどのようにして並べ替えを実現するアルゴリズムである。
#   -> 選択ソートがリスト内のデータから最小値を探索し、最小値から順に取り出すことで並べ替えを実現するアルゴリズムは何か?
#
# answer: 生体情報を変換した符号であるdna、顔、虹彩などや、公的な番号であるパスポート番号、マイナンバーなどである
# context:個人情報の例としては,マイナンバーやパスポート番号などの個人識別符号をあげることができる.同姓同名がいない場合は,氏名がわか
# れば個人を特定することができ,dna,虹彩,指紋,声紋などの生体情報も個人を識別するものとして利用することができる.
# example: 個人識別符号とは具体的にどのようなものですか
#   -> 個人情報の例としてはどのようなものがありますか
#   -> 個人情報の例としてはどのようなものが挙げられますか
#   -> 個人情報の例としてどのようなものがありますか
#   -> 個人情報の例としてはどのようなものがありますか?
#   -> 個人情報の例としてはどのようなものがあるか
#   -> 個人情報の例としてどのようなものが挙げられますか
#   -> 個人情報の例としてはどんなものがありますか
#   -> 個人情報の例としてはどのようなものがあるか?
#   -> 個人情報の例としてはどのようなものが挙げられますか?
#   -> 個人情報の例としてどのようなものがありますか?
#   -> 個人情報の例としては,どのようなものがありますか
#   -> 個人情報の例としては何がありますか
#   -> 個人情報の例としては,どのようなものが挙げられますか
#   -> 個人情報の例としてはどんなものが挙げられますか
#   -> 個人情報の例としてどんなものがありますか
#   -> 個人情報の例としてはどんなものがありますか?
#   -> 個人情報の一例を答えなさい。
#   -> 個人情報の例としてどのようなものが挙げられますか?
#   -> 個人情報の例としては、どのようなものがありますか
#   -> 個人情報の例はどのようなものですか
#
# answer: 通信プロトコル
# context:インターネットの通信において、通信する際の規定を定めたものを通信プロトコルという。このプロトコルがあることで相互に通信を行う
# ことが可能になっている。
# example: インターネットの通信において通信する際の規定を定めたものは何ですか
#   -> インターネットの通信において、通信する際の規定を定めたものを何というか
#   -> インターネットの通信において、通信する際の規定を定めたものを何というか。
#   -> インターネットの通信において、通信する際の規定を定めたものは何というか。
#   -> インターネットの通信において、通信する際の規定を定めたものは何というか
#   -> インターネットの通信において、通信する際の規定を定めたものは何か。
#   -> インターネットの通信において、通信する際の規定を定めたものは何ですか?
#   -> インターネットの通信において、通信する際の規定を定めたものを何というか答えなさい。
#   -> インターネットの通信において、通信する際の規定を定めたものを何といいますか
#   -> インターネットの通信において、通信する際にの規定を定めたものを何というか
#   -> インターネットの通信において、通信する際にの規定を定めたものを何というか。
#   -> インターネットの通信において、通信する際の規定を定めたものは何といいますか
#   -> インターネットの通信において、通信する際の規定を定めたものは何ですか
#   -> インターネットの通信において、通信する際の規定を定めたものは何というか答えなさい。
#   -> インターネットの通信において、通信する際の規定を定めたものを何といいますか?
#   -> インターネットの通信において、通信する際に規定を定めたものを何というか
#   -> インターネットの通信において、通信する際に規定を定めたものは何というか
#   -> インターネットの通信において、通信する際にの規定を定めたものは何というか。
#   -> インターネットの通信において、通信する際の規定を定めたものを何というか?
#   -> インターネットの通信において、通信する際の規定を定めたものは何といいますか?
#   -> インターネットの通信において、通信する際にの規定を定めたものは何というか
#
# answer: 知的財産権
# context:知的財産権とは,人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与えるようにした制度である。知的財産
# 権は,申請の必要な産業に関する産業財産権と,申請の必要がない文化や芸術に関する著作権に大きく分けられる。
# example: 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与えるようにした制度をなんという?
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与えるようにした制度を何というか
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与えるようにした制度を何というか
#   -> 人間の幅広い知的創造活動の成果について,ある創作者に一定期間の権利保護を与えるようにした制度を何というか
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与える制度を何というか
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与えるようにした制度を何というか?
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与えるようにした制度を何というか。
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与えるようにした制度を何と言うか
#   -> 人間幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与えるようにした制度を何というか
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与えるようにした制度を何というか?
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与えるようにした制度を何というか。
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与えるようにした制度を何といいますか
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与えるようにした制度を何といいますか?
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与える制度を何というか
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与えるようにした制度は何か。
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与えるようにした制度が何ですか?
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与えるようにした制度を何と言うか
#   -> 人間の幅広い知的創造活動の成果に対して,創作者に一定期間の権利保護を与えるようにした制度を何というか
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与えるようにした制度を何といいますか
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与えるようにした制度を何と言うか?
#   -> 人間幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与えるようにした制度を何というか
#
# answer: 個人情報を持つ企業や行政に対し、開示、訂正、利用停止等を求めることができる
# context:我々は,個人情報を持つ企業や行政機関について,開示,訂正,利用停止等を求めることができる権利が保障されているので,これらを適
# 切に行使して自分の個人情報を適切に保つことができる.
# example: 我々は個人情報を持つ企業や行政に対しどのような権利を保障されていますか
#   -> 個人情報を持つ企業や行政機関について、開示、訂正、利用停止等を求めることができる権利が保障されているのはなぜか
#   -> 個人情報を持つ企業や行政機関について,開示、訂正、利用停止等を求めることができる権利が保障されているのはなぜか
#   -> 個人情報を持つ企業や行政に対し、開示、訂正、利用停止等を求めることができる権利が保障されているのはなぜか
#   -> 個人情報を持つ企業や行政機関に対して開示、訂正、利用停止等を求めることができる権利が保障されているのはなぜか
#   -> 個人情報を持つ企業や行政に対して開示、訂正、利用停止等を求めることができる権利が保障されているのはなぜか
#   -> 個人情報を持つ企業や行政機関について開示、訂正、利用停止等を求めることができる権利が保障されているのはなぜか
#   -> 個人情報を持つ企業や行政に対して、開示、訂正、利用停止等を求めることができる権利が保障されているのはなぜか
#   -> 個人情報を持つ企業や行政機関に対してどのような権利が保障されているか
#   -> 個人情報を持つ企業や行政機関に開示、訂正、利用停止等を求めることができる権利が保障されているのはなぜか
#   -> 個人情報を持つ企業や行政機関に対してどのような権利が保障されていますか
#   -> 個人情報を持つ企業や行政機関について、開示、訂正、利用停止等を求めることができる権利が保障されているのはどのような種類の権利か
#   -> 個人情報を持つ企業や行政機関について、開示、訂正、利用停止等を求めることができる権利が保障されているのはどのような種類の権利ですか
#   -> 個人情報を持つ企業や行政機関に対してどのような権利が保障されているか?
#   -> 個人情報を持つ企業や行政に対し、開示、訂正、利用停止等を求めることができる権利が保障されているのはどのような種類の権利か
#   -> 個人情報を持つ企業や行政機関について,開示、訂正、利用停止等を求めることができる権利が保障されているのはどのような種類の権利か
#   -> 個人情報を持つ企業や行政機関について,開示、訂正、利用停止等を求めることができる権利が保障されているのはどのような種類の権利ですか
#   -> 個人情報を持つ企業や行政機関についてどのような権利が保障されていますか
#   -> 個人情報を持つ企業や行政機関について、開示、訂正、利用停止等を求めることができる権利が保障されているのはなぜか。
#   -> 個人情報を持つ企業や行政機関について,開示、訂正、利用停止等を求めることができる権利が保障されているのはなぜか。
#   -> 個人情報を持つ企業や行政機関について、開示、訂正、利用停止等を求めることができる権利が保障されているのはどのような場合ですか
#
# answer: 紙
# context:旧石器時代の人類は、壁画などを用いて情報を伝えることもあったと考えられる。その後、楔形文字やヒエログリフなどの文字が生まれ、
# 紙の普及により筆記のコミュニケーションが盛んになった。
# example: 何の普及によって筆記のコミュニケーションが盛んになったか答えなさい。
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、人類はどのような媒体を用いて情報を伝えたと考えられるか。
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、どのような素材が使われ始めたのですか?
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、どのような媒体が普及したか。
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、人類はどのような素材で情報を伝えたのだろうか
#   -> どのような素材が発明され、筆記のコミュニケーションが盛んになった。
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、人類はどのような素材で情報を伝えたか。
#   -> どのような素材が発明され、筆記のコミュニケーションが盛んになったか。
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、人類はどのような素材で情報を伝えたと考えられるか。
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、どのようなメディアが普及したか。
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、人類はどのような発明をしましたか?
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、どのような素材が発明されたのですか?
#   -> 楔形文字やヒエログリフなどの文字が生まれ、筆記のコミュニケーションが盛んになったのはなぜか。
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、人類はどのような素材で情報を伝えたのですか?
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、どのような媒体が普及したか?
#   -> 楔形文字やヒエログリフなどの文字が生まれ、どのような媒体が発明されたことによって筆記のコミュニケーションが盛んになったか。
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、人類はどのような媒体を用いて情報を伝えたと考えられるか
#   -> 楔形文字やヒエログリフなどの文字が生まれ、どのような媒体が発明されたことによって筆記のコミュニケーションが盛んになったか?
#   -> 楔形文字やヒエログリフなどの文字が生まれた後、どのような素材が使われ始めたのでしょうか。
#
# answer: 正しくない
# context:ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残りにくい、3.不特定多数が被害を受ける、4.時間と空間の
# 制約がない、の４つの特徴がある．
# example: 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には次のような特徴がある。1.匿名性が低い2.痕跡が残りやすい3.不特定多数が被害を受ける4.時間と空間の制約がある
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残しやすい、3.時間と空間の制約がない、5.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残にくい、3.時間と空間の制約がない、5.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残しやすい、3.時間と空間の制約がない、4.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残らない、3.時間と空間の制約がない、5.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残にくい、3.時間と空間の制約がない、4.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残らない、3.時間と空間の制約がない、4.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残しやすい、3.時間と空間の制約がない、4.時間の制約がない、5.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残にくい、3.時間と空間の制約がない、4.時間と空間の制約がない、の5つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残しやすい、3.時間と空間の制約がない、4.時間と空間の制約がない、の5つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残らない、3.時間と空間の制約がない、4.時間と空間の制約がない、の5つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残らない、3.時間と空間の制約がない、4.時間の制約がない、5.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残しやすい、3.時間と空間の制約がない、4.時間と空間の制約がない、5.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残らない、3.時間と空間の制約がない、4.時間と空間の制約がない、5.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残にくい、3.時間と空間の制約がない、4.時間の制約がない、5.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残にくい、3.時間と空間の制約がない、4.時間と空間の制約がない、5.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残りにくい、3.時間と空間の制約がない、4.時間と空間の制約がない、の4つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残しやすい、3.時間と空間の制約がない、4.時間と空間の制約がない、の4つの特徴がある
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残りにくい、3.時間と空間の制約がない、4.時間と空間の制約がない、の5つの特徴がある.
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残しやすい、3.時間と空間の制約がない、4.時間の制約がない、5.時間と空間の制約がない、の4つの特徴がある
#   -> 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残しやすい、3.時間と空間の制約がない、4.時間と空間の制約がない、5.時間と空間の制約がない、の4つの特徴がある
#
# answer: 生存する個人に関する情報で、氏名・生年月日その他の記述などで特定の個人を識別できるもの。または個人識別符号が含まれるもの。
# context:2003年に成立した「個人情報の保護に関する法律」(以下,「個人情報保護法」という)では,個人情報を以下のように定義している
# 。「生存する個人に関する情報であって,当該情報に含まれる氏名,生年月日その他の記述などによって特定の個人を識別できるもの(他の情報と容易に照
# 合することができ,それによって特定の個人を識別することができることとなるものを含む。),または個人識別符号が含まれるもの。」
# example: 2003年に成立した個人情報保護法における個人情報の定義を答えよ。
#   -> 個人情報とは何ですか
#   -> 個人情報とは何ですか?
#   -> 個人情報とは何か
#   -> 個人情報とは何か答えなさい。
#   -> 個人情報はどのように定義されていますか
#   -> 個人情報はどのように定義されますか
#   -> 個人情報とは何か。
#   -> 個人情報とは何か、答えなさい。
#   -> 個人情報とはどのようなものですか
#   -> 個人情報とは何か説明しなさい。
#   -> 個人情報とはどういう意味ですか
#   -> 個人情報は何と定義されますか
#   -> 個人情報とは何か?
#   -> 個人情報の定義は何ですか
#   -> 個人情報とはどのような種類の情報を指しますか
#   -> 個人情報はどのように定義されるか答えなさい。
#   -> 個人情報とはどのような種類の情報か答えなさい。
#   -> 個人情報とはどういう意味ですか?
#
# answer: kj法、特性要因図
# context:発散技法は多くの視点から多様な発想を生み出そうとする方法であり、主な発想法としてはブレーンストーミングやブレーンライティング
# がある。また、収束技法は集めたデータをまとめていくことで有効な情報を形成していく方法であり、kj法や特性要因図が該当する。統合技法は先述した
# 発散と収束を繰り返す方法であり、ワークデザイン法とインプットアウトプット法が該当する。態度技法は創造的態度を身に付ける方法でロールプレイング
# 、ワールドカフェがある。
# example: 収束技法にはどのような方法があるか、2つ答えなさい。
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成していく方法であり、何が該当するか。
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成していく方法であり、何が該当するか答えなさい。
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成していく方法を何というか
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成していく方法であり、主な発想法としてはどのような方法が該当するか。
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成していく方法であり、どのような法が該当するか。
#
# answer: 正しくない
# context:リモコンの赤外線センサは、赤外線による信号を検知する役割を果たしている。また、エアコンの温度センサ・湿度センサは、室内の気温
# ・湿度を検知する役割を果たしている。煙感知器の煙センサは煙を検知する役割を果たしている。
# example: 次の文章は正しいか答えなさい。エアコンの温度センサは煙を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。煙感知器の煙センサは煙を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。リモコンの赤外線センサは、赤外線による信号を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。エアコンの温度センサ・湿度センサは室内の気温・湿度を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。エアコンの温度センサ・湿度センサは、室内の気温・湿度を検知する役割を果たしている。
#   -> 次の文章は正しいか答えよ。煙感知器の煙センサは煙を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。煙感知器の煙センサーは煙を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。エアコンの温度センサ・湿度センサは、室内の気温や湿度を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。煙感知器の煙センサが煙を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。エアコンの温度センサ・湿度センサは室内の気温や湿度を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。煙感知器の煙センサは燃焼を検知する役割を果たしている。
#   -> 次の文章は正しいか答えてください。煙感知器の煙センサは煙を検知する役割を果たしている。
#   -> 次の文章は正しいですか?エアコンの温度センサ・湿度センサは、室内の気温・湿度を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。エアコンの温度センサ・湿度センサは室内の気温を検知する役割を果たしている。
#   -> 次の文章は正しいですか?エアコンの温度センサ・湿度センサは室内の気温・湿度を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。リモコンの赤外線センサーは、赤外線による信号を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。エアコンの温度センサ・湿度センサは、室内の気温を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。エアコンの温度センサー・湿度センサは室内の気温・湿度を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。煙感知器の煙センサは、煙を検知する役割を果たしている。
#   -> この文章は正しいか答えなさい。煙感知器の煙センサは煙を検知する役割を果たしている。
#   -> 次の文章は正しいか答えなさい。リモコンの赤外線センサが赤外線による信号を検知する役割を果たしている。
#
# answer: excel形式やcsv形式
# context:オープンデータとして利用しやすいファイル形式がある.統計情報,施設一覧など表形式となっている情報にはexcel形式やcsv形
# 式を用いる.報告書などの文章による情報や図形,画像などが混在する情報にはpdf形式やword形式を用いる.地図と組み合わせて利用する情報で,
# 線や面などのデータを含むものにはshp形式を用いる.
# example: 表形式に適したファイル形式は何?
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式が使われていますか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式が用いられるか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式を用いるか
#   -> 統計情報,施設一覧など表形式となっている情報にはどのようなファイル形式が用いられるか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式がありますか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式が使われますか
#   -> 統計情報,施設一覧など表形式となっている情報にはどのようなファイル形式が使われていますか
#   -> 統計情報,施設一覧など表形式となっている情報にはどのようなファイル形式を用いるか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式が利用できますか
#   -> 統計情報,施設一覧など表形式となっている情報にはどのようなファイル形式が使われますか
#   -> 統計情報,施設一覧など表形式となっている情報にはどのようなファイル形式がありますか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式が使用されますか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式を利用できますか
#   -> 統計情報,施設一覧など表形式となっている情報にはどのようなファイル形式が使用されますか
#   -> 統計情報,施設一覧など表形式となっている情報にはどのようなファイル形式が利用できますか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式が用いられますか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式が用いられていますか
#   -> 統計情報,施設一覧など表形式となっている情報にはどのようなファイル形式を利用できますか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式を使用するか
#   -> 統計情報,施設一覧など表形式となっている情報にはどのようなファイル形式が用いられますか
#
# answer: sql
# context:データの蓄積や検索が容易にできるものをデータベースという,そのうち特にリレーショナルデータベース(関係データベース)が広く用
# いられている。リレーショナルデータベースは,表形式で表現されたテーブルというデータの集合として管理する。複数のテーブルを関連付けて,結合して
# 利用することもできる。リレーショナルデータベースを操作するには,sql(structured query
# language)という言語が用いられる。
# example: リレーショナルデータベースを操作するプログラミング言語は何?
#   -> リレーショナルデータベースを操作する言語は何ですか?
#   -> リレーショナルデータベースを操作する言語は何ですか
#   -> リレーショナルデータベースを操作する言語は何か
#   -> リレーショナルデータベースを操作するにはどのような言語が使われますか
#   -> データの蓄積や検索が容易にできるリレーショナルデータベースを操作する言語は何ですか
#   -> リレーショナルデータベースを操作するにはどのような言語が用いられるか
#   -> データの蓄積や検索が容易にできるデータベースを操作する言語は何ですか
#   -> リレーショナルデータベースを操作する言語の名前は何ですか?
#   -> データの蓄積や検索が容易にできるリレーショナルデータベースを操作する言語は何か
#   -> リレーショナルデータベースを操作する言語は何か?
#   -> リレーショナルデータベースを操作する言語は何といいますか
#   -> データの蓄積や検索が容易にできるリレーショナルデータベースを操作する言語は何ですか?
#   -> リレーショナルデータベースを操作するにはどんな言語が使われますか
#   -> リレーショナルデータベースを操作するにはどのような言語が用いられるか。
#   -> リレーショナルデータベースを操作する言語の名前は何ですか
#   -> リレーショナルデータベースを操作する言語は何といいますか?
#   -> データの蓄積や検索が容易にできるデータベースを操作する言語は何か
#   -> リレーショナルデータベースを操作する言語は何?
#   -> リレーショナルデータベースを操作するにはどのような言語が使われていますか
#
# answer: 正しくない
# context:デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワーク、データベース、データ分析など、コンテンツ以外
# にも多岐に渡るものである。広い意味では組織や文化などもデザインの対象になりうる。
# example: 次の文章は正しいか答えなさい。データ分析やデータベースはデザインの対象にはならない。
#   -> 次の文章は正しいか答えなさい。デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワークなど、コンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワークなど多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象は、インターフェース、アルゴリズム、プログラミングなど、コンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象はインターフェース、アルゴリズム、プログラミング、ネットワークなど、コンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワークなど、コンテンツ以外にも多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象はインターフェース、アルゴリズム、プログラミング、ネットワークなど多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象はインターフェース、アルゴリズム、プログラミングなど、コンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワーク、データベース、データ分析など、コンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいか答えよ。デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワークなど、コンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいですか?デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワークなど、コンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象は、インターフェース、アルゴリズム、プログラミングなど、コンテンツ以外にも多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象がインターフェース、アルゴリズム、プログラミング、ネットワーク、データベース、データ分析など、コンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象はインターフェース、アルゴリズム、プログラミング、ネットワーク、データベース、データ分析など、コンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象は、インタフェース、アルゴリズム、プログラミング、ネットワークなど、コンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象はインターフェース、アルゴリズム、プログラミング、ネットワークなど、コンテンツ以外にも多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワークなど、コンテンツ以外に多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象はインターフェース、アルゴリズム、プログラミングなど、コンテンツ以外にも多岐に渡るものである。
#   -> 次の文章は正しいですか?デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワークなど多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワークなどコンテンツ以外の多岐に渡るものである。
#   -> 次の文章は正しいか答えなさい。インターフェース、アルゴリズム、プログラミング、ネットワークなど、コンテンツ以外の多岐に渡るものである。
