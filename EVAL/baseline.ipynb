# %% [markdown]
# ## 問題生成器の準備

# %%
from tqdm.auto import tqdm
import pandas as pd
from pprint import pprint

INPUT_MAX_LEN = 512  # モデルに入力されるトークン列の最大長。最大長を超えたトークンは切り捨てられる。
OUTPUT_MAX_LEN = 128  # モデルから出力されるトークン列の最大長。最大長を超えないように文が生成されるはず。
MODEL_NAME = "sonoisa/t5-base-japanese-question-generation"

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import T5ForConditionalGeneration

# 学習済みモデル
fine_tune_model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)

# GPUの利用有無
USE_GPU = torch.cuda.is_available()
if USE_GPU:
    fine_tune_model.cuda()
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
from transformers import T5Tokenizer

# トークナイザー（SentencePiece）
fine_tune_tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME, is_fast=True)

# %% [markdown]
# ## データセットの準備

# %%
test_dataset = "./data/test.csv"

question_data_list = []

df = pd.read_csv(test_dataset)

for index, row in df.iterrows():
    question_data_list.append((row["answer"], row["passage"], row["question"]))

# %% [markdown]
# ## 問題生成

# %%
generated_questions = []
csv_output = []

for answer, context, example in tqdm(question_data_list):
  # モデルに入力可能な形式に変換する。
  if answer == "" or context == "" or example == "": # 空行があれば処理を飛ばす
    continue

  input = f"answer: {answer.lower()} context: {context.lower()}"

  # 入力文をトークナイズする。
  tokenized_inputs = fine_tune_tokenizer.batch_encode_plus(
      [input], max_length=INPUT_MAX_LEN, truncation=True, 
      padding="longest", return_tensors="pt")

  input_ids = tokenized_inputs['input_ids']
  input_mask = tokenized_inputs['attention_mask']
  if torch.cuda.is_available():
    input_ids = input_ids.cuda()
    input_mask = input_mask.cuda()

  # 問題文を生成する。
  tokenized_outputs = fine_tune_model.generate(input_ids=input_ids, attention_mask=input_mask, 
    max_length=OUTPUT_MAX_LEN, return_dict_in_generate=True, decoder_start_token_id=0,
    # temperature=1.0,  # 生成にランダム性を入れる温度パラメータ
    num_beams=20,  # ビームサーチの探索幅
    # diversity_penalty=0.1,#1.0,  # 生成結果の多様性を生み出すためのペナルティパラメータ
    # num_beam_groups=4,  # ビームサーチのグループ
    num_return_sequences=20,  # 生成する文の数
    repetition_penalty=10.0, # 同じ文の繰り返し（モード崩壊）へのペナルティ
    # ,early_stopping=True
    )

  # 生成された問題文のトークン列を文字列に変換する。
  outputs = [fine_tune_tokenizer.decode(ids, skip_special_tokens=True, clean_up_tokenization_spaces=False) 
    for ids in tokenized_outputs.sequences]

  generated_questions.append(outputs)

  ## csv出力用
  for output in outputs:
      csv_output.append([answer, context, output])

import textwrap

for (answer, context, example), questions in zip(question_data_list, generated_questions):
  print(f"answer: {answer}")
  print("\n".join(textwrap.wrap(f"context:{context}")))
  print(f"example: {example}")
  for question in questions:
    print(f"  -> {question}")
  print()

## output csv
df = pd.DataFrame(csv_output, columns=["answer", "passage", "question"])
df.to_csv("./generated/T5.csv")

## cacheクリア
torch.cuda.empty_cache()
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# answer: 正しい
# context:どのようなアルゴリズムでも、処理の流れは、順次、分岐、反復の3つの構造の組み合わせで構成されている。このような処理の流れを制
# 御構造という。順次とは1つ1つの処理を順番に行うことであり、分岐はある条件に応じて異なる処理を実行することである。また、反復はある条件が満た
# されている間はその処理を繰り返し実行することである。
# example: 次の文章は正しいか答えなさい。どのようなアルゴリズムでも、処理の流れは、順次、分岐、反復の3つの構造の組み合わせで構成されている。
#   -> 順次と分岐は、どのような処理を順番に行っていますか?
#   -> 順次と分岐はどのような処理を実行しますか?
#   -> 順次、分岐、および反復の順序はどのようなものですか?
#   -> 順次と分岐はどのような処理を順番に行っていますか?
#   -> 順次と分岐の違いは何ですか?
#   -> 順次と分岐のどちらが正しいか?
#   -> 順次と分岐は、どのような処理を順番に行っていますか
#   -> 順次と分岐は、どのような処理を順番に実行しますか?
#   -> 順次と分岐のどちらが正しい処理を実行しますか?
#   -> 順次、分岐、および反復の3つの構造を組み合わせると、どのような結果が得られるか
#   -> 順次、分岐、および反復の順序はどのようなものですか
#   -> 順次、分岐、および反復の3つの構造のうちどちらが正しいか
#   -> 順次と分岐のどちらが正しいか
#   -> 順次、分岐、そして反復の3つの構造のうちどちらが正しいか
#   -> 順次、分岐、そして反復の順序はどのようなものですか?
#   -> 順次、分岐、反復の順序はどのようなものですか?
#   -> 順次と分岐はどのような処理を実行しているか
#   -> 順次と分岐はどのような処理を実行していますか?
#   -> すべてのアルゴリズムで、処理の流れの順序はどのようなものですか?
#   -> 順次と分岐はどのような処理を順番に行っていますか
#
# answer: cpuの動作速度が速く、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuとなる。
# context:cpuの動作速度が速いほど、1動作あたりに実行する命令や処理するデータが多いほど性能の良いcpuとなる。
# example: 性能の良いcpuとはどのようなものでしょう
#   -> cpuのパフォーマンスはどうなっていますか?
#   -> cpuの動作速度が速いほど、性能の良いcpuはどうなるか
#   -> cpuの動作速度が速いほど、性能の良いcpuはどうなるだろうか
#   -> cpuのパフォーマンスはどうなっていますか
#   -> cpuの動作速度が速いほど、性能の良いcpuはどれくらいになりますか?
#   -> context: cpuの動作速度が速いほど、性能の良いcpuはどうなるか
#   -> context: cpuの動作速度が速いほど、性能の良いcpuはどうなるか?
#   -> cpuの動作速度が遅いほど、性能の良いcpuはどうなるか
#   -> cpuの速度は速いですか、遅いですか?
#   -> cpuの動作速度が速いほど、性能の良いcpuはどうなるか?
#   -> cpuのパフォーマンスはどうなりますか?
#   -> cpuの動作速度が速いほど、性能の良いcpuはどうなりますか?
#   -> cpuの動作速度が速いほど、性能の良いcpuはどうなるのでしょうか?
#   -> cpuの実行命令は遅いですか、遅いですか?
#   -> cpuは、1動作あたりの実行命令や処理するデータが多いほど性能が良いですか?
#   -> cpuは、1動作あたりの実行命令や処理するデータが多いほど性能が良い
#   -> context: cpuの動作速度が速いほど、性能の良いcpuはどうなるだろうか
#   -> cpuの動作速度が速いほど、性能の良いcpuはどうなるのか
#   -> cpuの動作速度が速いほど、性能の良いcpuはどれくらいになりますか
#   -> cpuのパフォーマンスはどのくらいですか?
#
# answer: 正しくない
# context:pythonでは分岐にはif/elseを使い、反復にはwhile、forを使用する。
# example: 次の文章は正しいですか?pythonでは分岐にはwhile、forを使用する。
#   -> pythonの分岐は間違っていますか、間違っていますか?
#   -> pythonの分岐は正しくないのか、間違っているのか?
#   -> pythonの分岐は正しくないのか間違っているのか?
#   -> pythonの分岐が正しくないとき、それは何と呼ばれますか?
#   -> pythonの分岐は正しくないが、forは何をすべきか?
#   -> pythonの分岐にはどのような属性がありますか?
#   -> pythonの分岐が正しくない場合、それは何と呼ばれますか?
#   -> pythonでは、if/elseを省略するとどうなりますか?
#   -> pythonの分岐は正しくないか間違っているか?
#   -> pythonの分岐は正しくないのか、それとも間違っているのか?
#   -> pythonの分岐にはどのようなエラーがありますか?
#   -> pythonでは、if/elseは正しくないのか、それとも正しくないのか?
#   -> pythonでは、if/elseとforを比較するとき、どちらが正しくないと判断されるか?
#   -> pythonでは、分岐の際にエラーが出ることがあるのですか、それとも正しくないのですか?
#   -> pythonの分岐は正しくないのか、それとも正しくないのか?
#   -> pythonの分岐は正しくない、間違っていますか?
#   -> pythonでは、if/elseは何を表していますか?
#   -> pythonの分岐予測は、正しくないか間違っているか?
#   -> pythonでは、分岐の際にエラーが出ることがあるので、それを訂正しますか?
#   -> pythonでは、if/elseとforを比較するとき、どちらが正しくないと言いますか?
#
# answer: 正しくない
# context:現在のコンピュータの演算装置は、0か1のみで表現される2進数を扱うように設計されている。2進数を大きな桁で非常に高速で演算す
# ることによりすべての演算を行う。その基本的な演算は四則演算とは異なりand、or、notの3つである。
# example: 次の文章は正しいか答えなさい。現在のコンピュータの演算装置は、0から9で表現される10進数を扱うように設計されている。
#   -> 2進数では何が正しくないのですか?
#   -> 2進数では何が正しく表示されないのですか?
#   -> 4進数では、and、or、notの3つの結果はどうなりますか?
#   -> 2進数では、四則演算と矛盾していますか、それとも正しくないですか?
#   -> 2進数では何が正しく表示されないのか?
#   -> 4進数では、and、or、notの3つの結果はどうなっていますか?
#   -> 4進数では、and、or、notの3つの結果はどちらが正しくないですか?
#   -> 2進数では何が正しくないのか?
#   -> 2進数では、四則演算と矛盾していますか、それとも正しくありませんか?
#   -> 4進数では、and、or、notの3つの演算をどちらが正しく実行するか
#   -> 4進数では何が正しくないのですか?
#   -> 4進数では、and、or、notの3つの結果はどうなるか
#   -> 2進数では、四則演算と矛盾していますか、それとも正しくていませんか?
#   -> 四則演算と比較した場合、どちらが正しくないのですか?
#   -> 4進数では、and、or、notの3つの結果はどちらが正しくないのか?
#   -> 2進数に関する四則演算は正しくないですか、間違っていますか?
#   -> 4則演算と比較した場合、どちらが正しくないのか?
#   -> 4則演算と比較した場合、どちらが正しくないのですか?
#   -> 4進数では、and、or、notの3つの結果はどうなりますか
#   -> 4進数では、and、or、notの3つの結果はどうなっていますか
#
# answer: アイソタイプの目的は、言語の壁を越えて情報を伝達することで、社会的不平等を解消することである。
# context:オットー・ノイラートが考案したアイソタイプは、文字が読めない社会的弱者を含めた、あらゆる人々に向けて、情報をグラフィカルに伝
# 達しようとしたものである。その目的は、言語の壁を越えて情報を伝達することで、社会的な不平等を解消しようとしたものと言われている。
# example: アイソタイプの目的は何か、答えなさい。
#   -> オットー・ノイラートはアイソタイプをどのように説明しましたか?
#   -> オットー・ノイラートが考案したアイソタイプの名前は何ですか?
#   -> オットー・ノイラートが考案したアイソタイプとは?
#   -> オットー・ノイラートは何を発明したのですか?
#   -> オットー・ノイラートが考案したアイソタイプとは何ですか?
#   -> オットー・ノイラートはアイソタイプを発明したのですか?
#   -> オットー・ノイラートはアイソタイプを発明したことで知られている
#   -> オットー・ノイラートが考案したアイソタイプは何ですか?
#   -> オットー・ノイラートはアイソタイプを何のために考案したのか?
#   -> オットー・ノイラートはアイソタイプを発明した?
#   -> オットー・ノイラートはアイソタイプを考案したのですか?
#   -> オットー・ノイラートはアイソタイプを発明したのか?
#   -> オットー・ノイラートはアイソタイプをどのように考え出したのですか?
#   -> オットー・ノイラートのアイソタイプとは何ですか?
#   -> オットー・ノイラートはアイソタイプをどのように説明したのですか?
#   -> オットー・ノイラートはアイソタイプを何のために考案したのですか?
#   -> オットー・ノイラートはアイソタイプをどのように説明したか?
#   -> オットー・ノイラートはアイソタイプと何を結合したのか?
#   -> オットー・ノイラートはアイソタイプを発明したと伝えられている
#   -> オットー・ノイラートはアイソタイプと何を結合したのですか?
#
# answer: 正しくない
# context:離散グラフをコンピュータ上で表現するには、コンピュータで扱うことができるデータ形式で表現する必要がある。一つの例として、2次
# 元配列を用いて表現することができる。頂点どうしがつながっていれば1、つながっていなければ0として表現する。このように表現する方法を隣接行列と
# いう。隣接行列を用いて表現する場合、辺の本数が少ない場合には、隣接行列の要素の多くが0である疎行列になってしまう。
# example: 次の文章は正しいか答えてください。離散グラフを隣接行列を用いて表現する場合、辺の本数が少ない場合には蜜行列となる。
#   -> 隣接行列の要素の多くが0である疎行列はどうなりますか?
#   -> 疎行列とは何ですか?
#   -> 疎行列の要素の多くが0であるとはどういうことですか?
#   -> 辺の本数が少ないと、隣接行列の要素の多くが0である疎行列はどうなりますか?
#   -> 辺の本数が少ないと、疎行列はどうなりますか?
#   -> 疎行列は正しくないですか、間違っていますか?
#   -> 疎行列が正しくない場合、辺の本数が少ない場合はどうなりますか?
#   -> 辺の本数が多いと、疎行列はどうなりますか?
#   -> 辺の本数が少ないと、疎行列の概念はどうなりますか?
#   -> 疎行列の要素の多くは0であるとはどういうことですか?
#   -> 疎行列が正しくない場合、辺の本数が少ないとどうなりますか?
#   -> 疎行列の正しい定義は何ですか?
#   -> 辺の本数が多いと、隣接行列の要素の多くが0である疎行列はどうなりますか?
#   -> 隣接行列の要素の多くが0である疎行列はどうなるか
#   -> 疎行列の要素のほとんどは0であるとはどういうことですか?
#   -> 疎行列が正しくない場合、辺の本数が多いとどうなりますか?
#   -> 辺がつながっていない場合はどうなりますか?
#   -> 疎行列の要素の大半は0であるとはどういうことですか?
#   -> 隣接行列の要素の多くが0である疎行列とはどういう意味ですか?
#   -> 隣接行列の要素の多くが0である疎行列はどうなるか?
#
# answer: プライバシーの権利
# context:19世紀末に米国の法律家であるサミュエル・d・ウォーレンスとルイス・d・ブランダイスが,一人にしておいてもらう権利(私生活を
# みだりに他人の目にさらされない権利)として「プライバシーの権利」を主張した。
# example: 19世紀末にサミュエル・d・ウォーレンスとルイス・d・ブランダイスにより提唱された、私生活をみだりに他人の目にさらされない権利の名称は?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したのだろうか
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したのか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したのだろうか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされないようにする権利として何を主張したのか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされないようにする権利として何を主張したのだろうか
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされない権利として何を主張したのか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされないようにする権利として何を主張したのだろうか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされない権利として何を主張したのだろうか
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされない権利として何を主張したのだろうか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張しましたか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされないようにする権利として何を主張したのか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされないようにする権利として何を主張しましたか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされないようにする権利として何を主張したのだろうか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされないようにする権利として何を主張したのだろうか
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされないことを可能にするために何を主張したのか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスが主張した権利は何ですか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされない権利として何を主張しましたか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、プライベートをみだりに他人の目にさらされないようにする権利として何を主張しましたか?
#   -> サミュエル・d・ウォーレンとルイス・d・ブランダイスは、私生活をみだりに他人の目にさらされない権利として何を主張したのか
#
# answer: 関数を用いることでプログラムを機能ごとに整理、構造化することが可能となる。また、作成した関数はメインコード内で何回でも呼び出すことが可能となるため、作成した機能を再利用することが可能となる。
# context:一般にシステム開発などで行われるプログラムは大規模なので、コードの長さも膨大となる。このような場合、文章の章、節、段落のよう
# な適切な構造を作らないと、コードの可動性は著しく低くなってしまう。そこでプログラムの機能ごとにメインコードから切り離し、関数という単位で分割
# することで、プログラムを機能ごとに整理、構造化することが可能となる。また、作成した関数はメインコード内で何回でも呼び出すことが可能となるため
# 、作成した機能を再利用することが可能となる。
# example: 関数を用いることにどのようなメリットがあるか
#   -> プログラムの機能ごとにメインコードから分離するとどうなりますか?
#   -> プログラムの機能ごとにメインコードから分離するとどうなりますか
#   -> コードをメインコードから分離するとどうなりますか?
#   -> プログラムの機能ごとにメインコードから分離するとどうなるか
#   -> 機能ごとにメインコードから分離するとどうなりますか?
#   -> コードをメインコードから分離するとどうなりますか
#   -> プログラムの機能ごとにメインコードから分離するとどうなるのですか?
#   -> コードの機能ごとにメインコードから分離するとどうなりますか?
#   -> 関数によってプログラムを分割するとどうなりますか?
#   -> プログラムの機能ごとにメインコードから分割するとどうなりますか?
#   -> コードをメインコードから分離するとどうなるのですか?
#   -> 機能ごとにメインコードから分離するとどうなりますか
#   -> プログラムの機能ごとにメインコードから分離するというのはどういうことですか?
#   -> 関数によってプログラムを分割するとどうなりますか
#   -> プログラムの機能ごとにメインコードから分離するとどうなるか?
#   -> コードの機能ごとにメインコードから分離するとどうなりますか
#   -> 関数を使ってプログラムを分割するとどうなりますか?
#   -> プログラムの機能ごとにメインコードから分離するというのはどういう意味ですか?
#   -> 関数を使ってプログラムを分割するとどうなるのですか?
#   -> 関数を使用してプログラムを分割するとどうなりますか?
#
# answer: 選択ソートはリスト内のデータから最小値を探索し、最小値から順に取り出すことで並べ替えを実現するアルゴリズムである。
# context:選択ソートはリスト内のデータから最小値を探索し、最小値から順に取り出すことで並べ替えを実現するアルゴリズムである。
# example: 選択ソートとはどのようなアルゴリズムか
#   -> リスト内のデータから最小値を探索するアルゴリズムはどれか
#   -> リスト内のデータから最小値を探索するアルゴリズムは何か
#   -> リスト内の最小値を探索するアルゴリズムは何か
#   -> リスト内のデータから最小値を探索して並べ替えるアルゴリズムは何か
#   -> リスト内の最小値を探索するアルゴリズムはどれか
#   -> リスト内のデータから最小値を探索するアルゴリズムは何と呼ばれているか
#   -> リスト内のデータから最小値を探索するアルゴリズムは何ですか
#   -> リスト内の最小値を探索するアルゴリズムは何と呼ばれているか
#   -> リスト内の最小値を探索して並べ替えるアルゴリズムは何か
#   -> リスト内のデータから最小値を探索して並べ替えることができるアルゴリズムは何か
#   -> リスト内のデータから最小値を探索して並べ替えを実現するアルゴリズムは何か
#   -> リスト内のデータから最小値を探索して並べ替えるアルゴリズムは何ですか
#   -> リスト内の最小値を探索するアルゴリズムはどれですか?
#   -> リスト内のデータから最小値を探索するアルゴリズムはどれですか
#   -> リスト内のデータから最小値を探索するアルゴリズムの名前は何ですか?
#   -> リスト内のデータから最小値を探索するアルゴリズムは何ですか?
#   -> リスト内のデータの最小値を探索するアルゴリズムは何か
#   -> リスト内のデータから最小値を探索して並べ替えるアルゴリズムは何ですか?
#   -> リスト内のデータから最小値を探索するアルゴリズムはどれですか?
#   -> リスト内の最小値を探索するアルゴリズムはどれですか
#
# answer: 生体情報を変換した符号であるdna、顔、虹彩などや、公的な番号であるパスポート番号、マイナンバーなどである
# context:個人情報の例としては,マイナンバーやパスポート番号などの個人識別符号をあげることができる.同姓同名がいない場合は,氏名がわか
# れば個人を特定することができ,dna,虹彩,指紋,声紋などの生体情報も個人を識別するものとして利用することができる.
# example: 個人識別符号とは具体的にどのようなものですか
#   -> 個人識別符号とは何か?
#   -> 個人識別符号にはどのようなものがありますか?
#   -> 個人識別符号とは何ですか?
#   -> 個人識別符号とは?
#   -> 個人識別符号にはどんなものがありますか?
#   -> 個人の識別符号にはどのようなものがありますか?
#   -> 個人を識別するものとして利用できるものは何ですか?
#   -> 個人識別符号とはどのようなものですか?
#   -> 個人を識別するものは何か?
#   -> 個人の識別符号にはどんなものがありますか?
#   -> 個人識別符号とは何か
#   -> 個人の識別符号とは何か?
#   -> 個人識別符号には何がありますか?
#   -> 個人の識別符号とは何ですか?
#   -> 個人を識別するものは何か
#   -> 個人識別符号の例は何ですか?
#   -> 個人識別符号の例を教えてください
#   -> 個人を識別するものの例をあげよ
#   -> 個人識別符号にはどのようなものがありますか
#   -> 個人を識別するものの例は何ですか?
#
# answer: 通信プロトコル
# context:インターネットの通信において、通信する際の規定を定めたものを通信プロトコルという。このプロトコルがあることで相互に通信を行う
# ことが可能になっている。
# example: インターネットの通信において通信する際の規定を定めたものは何ですか
#   -> インターネットの通信に関する規定は何と呼ばれていますか?
#   -> インターネットの通信において、規定を定めたものは何と呼ばれていますか?
#   -> インターネットの通信に関する規定を定めたものは何ですか?
#   -> インターネットの通信で規定を定めたものは何ですか?
#   -> インターネットの通信における規定は何と呼ばれていますか?
#   -> インターネットの通信についての規定を定めたものは何と呼ばれていますか?
#   -> インターネットの通信についての規定を定めたものは何ですか?
#   -> インターネットの通信に関しての規定を定めたものは何と呼ばれていますか?
#   -> インターネットの通信において、規定を定めたものは何と呼ばれているか
#   -> インターネットの通信に関する規定を定めたものは何と呼ばれていますか?
#   -> インターネットの通信のための規定は何と呼ばれていますか?
#   -> インターネットの通信で規定を定めたものは何と呼ばれていますか?
#   -> インターネットの通信における規定を定めたものは何ですか?
#   -> インターネットの通信に関しての規定を定めたものは何ですか?
#   -> インターネットの通信において、規定を定めたものは何ですか?
#   -> インターネットの通信の規定を定めたものは何と呼ばれていますか?
#   -> インターネットの通信の規定を定めたものは何ですか?
#   -> インターネットの通信の規定は何と呼ばれていますか?
#   -> インターネットの通信に関する規定を何といいますか?
#   -> インターネットの通信において規定を定めたものは何ですか?
#
# answer: 知的財産権
# context:知的財産権とは,人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与えるようにした制度である。知的財産
# 権は,申請の必要な産業に関する産業財産権と,申請の必要がない文化や芸術に関する著作権に大きく分けられる。
# example: 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与えるようにした制度をなんという?
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与える制度は何か
#   -> 人間の幅広い知的創造活動の成果について、誰が一定期間の権利を保護するのか?
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与える制度は何と呼ばれているか
#   -> 人間の幅広い知的創造活動の成果について,誰が一定期間の権利を保護するのか?
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与える制度とは何か
#   -> 人間の幅広い知的創造活動の成果について,何を定めていますか?
#   -> 人間の幅広い知的創造活動の成果について、何を定めていますか?
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与える制度は何か
#   -> 人間の幅広い知的創造活動の成果について、創作者に一定期間の権利保護を与える制度は何か
#   -> 人間の幅広い知的創造活動の成果について、その創作者に一定期間の権利保護を与える制度は何か
#   -> 人間の幅広い知的創造活動の成果について、誰が一定期間の権利を保護するのか
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与える制度は何と呼ばれていますか?
#   -> 人間の幅広い知的創造活動の成果について、誰が一定期間の権利を保護することができるか?
#   -> 人間の幅広い知的創造活動の成果について、創作者に一定期間の権利保護を与える制度は何と呼ばれているか
#   -> 人間の幅広い知的創造活動の成果について,創作者に一定期間の権利保護を与える制度は何と呼ばれているか
#   -> 人間の幅広い知的創造活動の成果について、その創作者に一定期間の権利保護を与える制度は何と呼ばれているか
#   -> 人間の幅広い知的創造活動の成果について,誰が一定期間の権利を保護することができるか?
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与える制度は何と呼ばれているか?
#   -> 人間の幅広い知的創造活動の成果について、誰が一定期間の権利保護を与えるのか?
#   -> 人間の幅広い知的創造活動の成果について,その創作者に一定期間の権利保護を与える制度とは何か?
#
# answer: 個人情報を持つ企業や行政に対し、開示、訂正、利用停止等を求めることができる
# context:我々は,個人情報を持つ企業や行政機関について,開示,訂正,利用停止等を求めることができる権利が保障されているので,これらを適
# 切に行使して自分の個人情報を適切に保つことができる.
# example: 我々は個人情報を持つ企業や行政に対しどのような権利を保障されていますか
#   -> 開示、訂正、利用停止を求めることができる権利は保障されていますか?
#   -> 我々は、開示、訂正、利用停止を求めることができる権利をどのように保障しているのだろうか
#   -> 我々は、開示、訂正、利用停止等を求めることができる権利をどのように保障しているのだろうか
#   -> 開示、訂正、利用停止の3つの権利は保障されていますか?
#   -> 開示、訂正、利用停止を求めることができる権利は何と呼ばれていますか?
#   -> 開示、訂正、利用停止を求めることができる権利とは何ですか?
#   -> 情報を適切に保持するためには何が保証されていますか?
#   -> 企業の開示、訂正、利用停止を求めることができる権利は保障されていますか?
#   -> 我々は、開示、訂正、利用停止を求めることができる権利を保障しているのだろうか
#   -> 情報の開示、訂正、利用停止を求めることができる権利は保障されていますか?
#   -> 我々は、開示、訂正、利用停止を求めることができる権利をどのように保障されているのだろうか
#   -> 開示、訂正、利用停止の3つの権利は保証されていますか?
#   -> 我々は、開示、訂正、利用停止を求めることができる権利をどのように確保しているのだろうか
#   -> 開示、訂正、利用停止を求めることができる権利はどのようなものですか?
#   -> 我々は、開示、訂正、利用停止等を求めることができる権利をどのように保障されているのだろうか
#   -> 個人情報を適切に保持するためには何が保証されていますか?
#   -> 我々は、開示、訂正、利用停止を求めることができる権利をどのように保障しているのだろうか?
#   -> 我々は、開示、訂正、利用停止を求めることができる権利をどのように保障しているのでしょうか?
#   -> 我々は、開示、訂正、利用停止の3つの権利を保障している
#   -> 我々は、開示、訂正、利用停止を求めることができる権利を保障しているのだろうか?
#
# answer: 紙
# context:旧石器時代の人類は、壁画などを用いて情報を伝えることもあったと考えられる。その後、楔形文字やヒエログリフなどの文字が生まれ、
# 紙の普及により筆記のコミュニケーションが盛んになった。
# example: 何の普及によって筆記のコミュニケーションが盛んになったか答えなさい。
#   -> どのような素材が書き言葉のコミュニケーションに役立ちましたか?
#   -> どのような素材が書き言葉に使われるようになったのですか?
#   -> どのような素材が筆記コミュニケーションに使われるようになったのですか?
#   -> 筆記はどのような素材で作られましたか?
#   -> 楔形文字とヒエログリフはどのような素材で作られましたか?
#   -> 楔形文字やヒエログリフはどのような素材で作られましたか?
#   -> どのような素材が筆記コミュニケーションに役立ちましたか?
#   -> 楔形文字やヒエログリフはどのような素材で作られたのですか?
#   -> 楔形文字やヒエログリフのような文字は、どのような素材で作られましたか?
#   -> 何が筆記のコミュニケーションに役立ちましたか?
#   -> どの素材が書き言葉のコミュニケーションに役立ちましたか?
#   -> 楔形文字やヒエログリフは、どのような素材で作られましたか?
#   -> 楔形文字やヒエログリフは、他に何が発明されたのですか?
#   -> 楔形文字とヒエログリフはどんな素材で作られましたか?
#   -> 楔形文字やヒエログリフは、どのような素材で書くのが一般的になりましたか?
#   -> 楔形文字とヒエログリフは、どのような素材で作られましたか?
#   -> どのような素材が筆記のコミュニケーションに役立ちましたか?
#   -> 楔形文字はどのような素材で作られましたか?
#   -> 楔形文字とヒエログリフは、他に何が発明されたのですか?
#   -> 楔形文字やヒエログリフは、どのような素材で書き言葉になったのですか?
#
# answer: 正しくない
# context:ネットワークを利用したサイバー犯罪には1.匿名性が高い、2.痕跡が残りにくい、3.不特定多数が被害を受ける、4.時間と空間の
# 制約がない、の４つの特徴がある．
# example: 次の文章は正しいか答えなさい。ネットワークを利用したサイバー犯罪には次のような特徴がある。1.匿名性が低い2.痕跡が残りやすい3.不特定多数が被害を受ける4.時間と空間の制約がある
#   -> サイバー犯罪は匿名性が高いのですか、それとも少ないのですか?
#   -> 匿名性とプライバシーのどちらが重要なのか?
#   -> 匿名性はどのような特徴ですか?
#   -> 匿名性と時間的制約のどちらがサイバー犯罪をより複雑にしているか?
#   -> 匿名性とプライバシーのどちらがサイバー犯罪に最も適しているか?
#   -> どのような種類の犯罪が匿名性と一致していませんか?
#   -> 匿名性と時間的制約のどちらがサイバー犯罪に最も適しているか?
#   -> どのようなタイプの犯罪が匿名性と一致していませんか?
#   -> 匿名性はどのような種類の犯罪と似ていますか?
#   -> 匿名性と時間的制約のどちらがサイバー犯罪を混乱させるのか?
#   -> 匿名性と時間的制約のどちらがサイバー犯罪を混乱させているのか?
#   -> 匿名性とプライバシーのどちらがサイバー犯罪をより安全に扱うか?
#   -> サイバー犯罪は匿名性が高いのですか、少ないのですか?
#   -> 匿名性と時間的制約のどちらがサイバー犯罪に適しているか?
#   -> 匿名性と時間的制約のどちらがサイバー犯罪をより複雑にしているか
#   -> 匿名性と時間的制約のどちらがサイバー犯罪に最も適しているか
#   -> 匿名性はどのような種類の犯罪よりも優れているか?
#   -> 匿名性と時間的制約のどちらが重要なのか?
#   -> 匿名性はどのような種類の犯罪に適用できるのか?
#   -> 匿名性と時間的制約のどちらがサイバー犯罪を難しくしているか?
#
# answer: 生存する個人に関する情報で、氏名・生年月日その他の記述などで特定の個人を識別できるもの。または個人識別符号が含まれるもの。
# context:2003年に成立した「個人情報の保護に関する法律」(以下,「個人情報保護法」という)では,個人情報を以下のように定義している
# 。「生存する個人に関する情報であって,当該情報に含まれる氏名,生年月日その他の記述などによって特定の個人を識別できるもの(他の情報と容易に照
# 合することができ,それによって特定の個人を識別することができることとなるものを含む。),または個人識別符号が含まれるもの。」
# example: 2003年に成立した個人情報保護法における個人情報の定義を答えよ。
#   -> 個人情報の定義にはどのようなものがありますか?
#   -> 個人情報の定義には何が含まれていますか?
#   -> 「個人情報保護法」は、何を「生存する個人に関する情報」と定義していますか?
#   -> 個人情報の定義は何ですか?
#   -> 個人情報の保護に関する法律は、何を「生存する個人に関する情報」と定義していますか?
#   -> 「個人情報保護法」は、何を「生存する個人に関する情報」と定義しているのだろうか
#   -> 「個人情報保護法」は、何を定義しているのですか?
#   -> 個人情報保護法には何が含まれていますか?
#   -> 「個人情報保護法」は、何をプライバシーと定義していますか?
#   -> 「個人情報保護法」は、何を「生存している個人に関する情報」と定義していますか?
#   -> 個人情報の保護に関する法律は、何を定義しているのですか?
#   -> 個人情報には何が含まれていますか?
#   -> 「個人情報保護法」は、何を「プライバシー」と定義していますか?
#   -> 「個人情報保護法」は、何を「生存する個人に関する情報」と定義しているか
#   -> 「個人情報保護法」には何が含まれていますか?
#   -> 「個人情報保護法」は、何をプライバシーと定義しているのですか?
#   -> 個人情報はどのように定義されていますか?
#   -> 「個人情報保護法」は、何を「生存する個人に関する情報」と定義しているのですか?
#   -> 「個人情報保護法」には、どのような種類の情報が含まれていますか?
#   -> 個人情報の「保護」とはどういう意味ですか?
#
# answer: kj法、特性要因図
# context:発散技法は多くの視点から多様な発想を生み出そうとする方法であり、主な発想法としてはブレーンストーミングやブレーンライティング
# がある。また、収束技法は集めたデータをまとめていくことで有効な情報を形成していく方法であり、kj法や特性要因図が該当する。統合技法は先述した
# 発散と収束を繰り返す方法であり、ワークデザイン法とインプットアウトプット法が該当する。態度技法は創造的態度を身に付ける方法でロールプレイング
# 、ワールドカフェがある。
# example: 収束技法にはどのような方法があるか、2つ答えなさい。
#   -> 収束技法にはどのようなものがありますか?
#   -> 収束技術にはどのようなものがありますか?
#   -> 収束プロセスにはどのようなものがありますか?
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成する方法ですか?
#   -> 収束技法にはどんなものがありますか?
#   -> 収束過程で集めたデータをまとめていくことで有効な情報を形成する方法にはどのようなものがありますか?
#   -> 収束テクニックにはどのようなものがありますか?
#   -> 収束法にはどのようなものがありますか?
#   -> 収束過程で集めたデータをまとめていくことで有効な情報を形成する方法には、どのようなものがありますか?
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成する方法であり、どのようなものがありますか?
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成する方法である。具体的にはどのようなものがありますか?
#   -> 収束技法の例をあげよ
#   -> 収束技法とは何ですか?
#   -> 収束技法の例を教えてください
#   -> 収束メソッドにはどのようなものがありますか?
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成する方法である。どのようなものがありますか?
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成する方法であり、何が該当するか
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成する方法であり、どのような用語が使われるか
#   -> 収束技術にはどんなものがありますか?
#   -> 収束技法は集めたデータをまとめていくことで有効な情報を形成する方法を示していますか?
#
# answer: 正しくない
# context:リモコンの赤外線センサは、赤外線による信号を検知する役割を果たしている。また、エアコンの温度センサ・湿度センサは、室内の気温
# ・湿度を検知する役割を果たしている。煙感知器の煙センサは煙を検知する役割を果たしている。
# example: 次の文章は正しいか答えなさい。エアコンの温度センサは煙を検知する役割を果たしている。
#   -> 赤外線センサーは何を検出するのですか?
#   -> 赤外線センサーが正しく動作しない場合はどうなりますか?
#   -> 赤外線センサーは、信号を正しく認識しないとどうなりますか?
#   -> 赤外線センサは何を検出するのですか?
#   -> 赤外線センサーは、正しく動作しないとどうなりますか?
#   -> 赤外線センサーは、信号が正しくないときに誤動作しますか、間違っていますか?
#   -> 赤外線センサーが正しく動作しないとどうなりますか?
#   -> 赤外線センサーは、信号が正しくないときに誤動作する可能性があるのですか、間違っていますか?
#   -> 赤外線センサーが正しく動作しないと、信号はどうなりますか?
#   -> 煙感知器は、正しく動作しないとどうなりますか?
#   -> 赤外線センサは、信号が正しくないときに誤動作しますか、間違っていますか?
#   -> 赤外線センサーが正しく機能しないと、信号はどうなりますか?
#   -> 煙感知器の煙センサは、正しくないですか、間違っていますか?
#   -> 赤外線センサーは、正しくない信号を検出できるのですか、それとも間違っていますか?
#   -> 赤外線センサーは、信号を正しく認識しないとどうなるのですか?
#   -> 赤外線センサーは、どのような信号を正しく認識する必要があるか?
#   -> 赤外線センサーは、正しくない信号を検出できるのですか、間違っていますか?
#   -> 赤外線センサーが正しく動作しないと、信号はどうなるのですか?
#   -> 赤外線センサーはどのような信号を検出しますか?
#   -> 赤外線センサーが正しく機能しないと、信号はどうなるのですか?
#
# answer: excel形式やcsv形式
# context:オープンデータとして利用しやすいファイル形式がある.統計情報,施設一覧など表形式となっている情報にはexcel形式やcsv形
# 式を用いる.報告書などの文章による情報や図形,画像などが混在する情報にはpdf形式やword形式を用いる.地図と組み合わせて利用する情報で,
# 線や面などのデータを含むものにはshp形式を用いる.
# example: 表形式に適したファイル形式は何?
#   -> 統計情報や施設一覧はどのような形式を使っていますか?
#   -> 統計情報や施設一覧などはどのような形式を使っていますか?
#   -> 統計情報や施設一覧にはどのようなファイル形式がありますか
#   -> 統計情報や施設一覧にはどのようなファイル形式がありますか?
#   -> 統計情報や施設一覧はどのようなファイル形式を使っていますか?
#   -> 統計情報や施設一覧はどのようなファイル形式ですか?
#   -> 統計情報や施設一覧などはどのようなファイル形式ですか?
#   -> 統計情報や施設一覧などはどのようなファイル形式ですか
#   -> 統計情報や施設一覧はどのようなファイル形式を使用しますか?
#   -> 統計情報や施設一覧などの表形式となっている情報にはどのようなファイル形式がありますか
#   -> 統計情報や施設一覧など表形式になっている情報にはどのようなファイル形式がありますか
#   -> 統計情報や施設一覧など表形式となっている情報にはどのようなファイル形式がありますか
#   -> 統計情報や施設一覧はどのような形式を使っていますか
#   -> 統計情報や施設一覧にはどのような形式がありますか?
#   -> 統計情報や施設一覧はどのようなファイル形式ですか
#   -> 統計情報や施設一覧などはどのようなファイル形式を使っていますか?
#   -> 統計情報や施設一覧はどのような形式ですか?
#   -> 統計情報や施設一覧など表形式になっている情報にはどのようなファイル形式がありますか?
#   -> 統計情報や施設一覧などはどのような形式ですか?
#   -> 統計情報や施設一覧など表形式になっているものは何ですか?
#
# answer: sql
# context:データの蓄積や検索が容易にできるものをデータベースという,そのうち特にリレーショナルデータベース(関係データベース)が広く用
# いられている。リレーショナルデータベースは,表形式で表現されたテーブルというデータの集合として管理する。複数のテーブルを関連付けて,結合して
# 利用することもできる。リレーショナルデータベースを操作するには,sql(structured query
# language)という言語が用いられる。
# example: リレーショナルデータベースを操作するプログラミング言語は何?
#   -> リレーショナルデータベースを操作する言語は何ですか?
#   -> データベースを操作する言語は何ですか?
#   -> リレーショナル・データベースを操作する言語は何ですか?
#   -> リレーショナルデータベースを操作する言語は何ですか
#   -> リレーショナルデータベースを操作するには何を使用しますか?
#   -> リレーショナルデータベースを操作するには何を使いますか?
#   -> データベースを操作するには何を使いますか?
#   -> リレーショナルデータベースを操作する言語の名前は何ですか?
#   -> リレーショナルデータベースの操作言語は何ですか?
#   -> データベースを操作するには何を使用しますか?
#   -> リレーショナルデータベースを操作するには、どのような言語が使われますか?
#   -> リレーショナルデータベースを操作する言語は何と呼ばれていますか?
#   -> データベースを操作する言語は何ですか
#   -> リレーショナルデータベースを操作するにはどのような言語が使われますか?
#   -> リレーショナル・データベースを操作するには何を使用しますか?
#   -> リレーショナルデータベースを操作するにはどの言語を使用しますか?
#   -> リレーショナルデータベースを操作するにはどのような言語を使用しますか?
#   -> リレーショナルデータベースの操作にはどのような言語が使われますか?
#   -> リレーショナルデータベースを操作するには、どのような言語を使用しますか?
#   -> リレーショナルデータベースを操作するには、どのような言語が使用されますか?
#
# answer: 正しくない
# context:デザインの対象は、インターフェース、アルゴリズム、プログラミング、ネットワーク、データベース、データ分析など、コンテンツ以外
# にも多岐に渡るものである。広い意味では組織や文化などもデザインの対象になりうる。
# example: 次の文章は正しいか答えなさい。データ分析やデータベースはデザインの対象にはならない。
#   -> デザインが正しくないというのはどういうことですか?
#   -> デザインの対象がコンテンツ以外のものに限定されている場合、それは正しくないのか、それとも間違っているのか?
#   -> デザインの対象がコンテンツ以外のものに限定されている場合、それは正しくないのか、間違っているのか?
#   -> デザインの対象がコンテンツ以外のものに限定される場合、それは正しくないのか、それとも間違っているのか?
#   -> デザインの対象がコンテンツ以外の場合はどうなりますか?
#   -> デザインの対象がコンテンツ以外のものに限定される場合、それは正しくないのか、間違っているのか?
#   -> デザインのガイドラインは正しくないですか、間違っていますか?
#   -> デザインの対象がコンテンツ以外のものに限定されている場合、それは正しくないですか、それとも間違っていますか?
#   -> デザインの対象がコンテンツ以外のものに限定されている場合、それはどうなりますか?
#   -> デザインの対象がコンテンツ以外のものに限られている場合、それは正しくないのか、それとも間違っているのか?
#   -> デザインの対象にならないコンテンツは、正しくないですか、それとも間違っていますか?
#   -> デザインの対象がコンテンツ以外のものに限定される場合、それは正しくないですか、それとも間違っていますか?
#   -> デザインの対象がコンテンツ以外のものに限定している場合、それは正しくないのか、それとも間違っているのか?
#   -> デザインの対象がコンテンツ以外のものに限定されている場合、それは正しくないのか、それとも間違っているのか
#   -> デザインの対象がコンテンツ以外のものに限定している場合、それは正しくないのか、間違っているのか?
#   -> デザインのガイドラインは正しくないですか、それとも間違っていますか?
#   -> デザインの対象がコンテンツ以外のものに限定されている場合、それは正しくないのですか、それとも間違っていますか?
#   -> デザインの対象がコンテンツ以外のものに限られている場合、それはどうなりますか?
#   -> デザインの対象がコンテンツ以外のものに限定されている場合、それは正しくないですか、間違っていますか?
#   -> デザインの対象になっているコンテンツは、正しくないかもしれないし、間違っていますか?
